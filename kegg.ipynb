# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("KEGGREST")
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("KEGGgraph")
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("pathview")

# %%
library("KEGGREST")
library("KEGGgraph")
library("pathview")

# %%
total_path.l<-unique(keggLink("pathway","sce"))

# %%
a<-total_path.l[1]

# %%
path_id<-sapply(total_path.l,function(i) strsplit(i,split="sce")[[1]][2])

# %%
length(path_id)
# Out:
# [1] 116

# %%
sapply(path_id,function(i){
    download.kegg(pathway.id = i, species = "sce", kegg.dir = ".",file.type=c("xml"))
})

# %%
gR <- parseKGML2Graph("sce04070.xml",expandGenes=TRUE)
nodes(gR)
# Out:
#  [1] "sce:YDR315C" "sce:YPL268W" "sce:YBR109C" "sce:YPR113W" "sce:YDR208W"
#  [6] "sce:YFR019W" "sce:YJL100W" "sce:YLR305C" "sce:YNL267W" "sce:YBR029C"
# [11] "sce:YIL002C" "sce:YNL106C" "sce:YOR109W" "sce:YDR173C" "sce:YDR287W"
# [16] "sce:YHR046C" "sce:YOL065C" "sce:YJR110W" "sce:YDR017C" "sce:YLR410W"
# [21] "sce:YLR240W" "sce:YBL105C" "sce:YKL212W"

# %%
edges(gR)
# Out:
# $`sce:YDR315C`
# [1] "sce:YDR173C"
#
# $`sce:YPL268W`
#  [1] "sce:YFR019W" "sce:YJR110W" "sce:YPR113W" "sce:YOL065C" "sce:YPL268W"
#  [6] "sce:YDR208W" "sce:YIL002C" "sce:YNL106C" "sce:YOR109W" "sce:YJL100W"
# [11] "sce:YLR305C" "sce:YNL267W" "sce:YDR287W" "sce:YHR046C" "sce:YLR240W"
# [16] "sce:YDR173C"
#
# $`sce:YBR109C`
# character(0)
#
# $`sce:YPR113W`
# [1] "sce:YFR019W" "sce:YJR110W" "sce:YDR287W" "sce:YHR046C" "sce:YBR029C"
# [6] "sce:YJL100W" "sce:YLR305C" "sce:YNL267W" "sce:YLR240W"
#
# $`sce:YDR208W`
# [1] "sce:YJL100W" "sce:YLR305C" "sce:YNL267W" "sce:YIL002C" "sce:YNL106C"
# [6] "sce:YOR109W" "sce:YPL268W"
#
# $`sce:YFR019W`
# [1] "sce:YJR110W" "sce:YJL100W" "sce:YLR305C" "sce:YNL267W" "sce:YLR240W"
#
# $`sce:YJL100W`
# [1] "sce:YIL002C" "sce:YNL106C" "sce:YOR109W" "sce:YPL268W" "sce:YJR110W"
# [6] "sce:YLR240W"
#
# $`sce:YLR305C`
# [1] "sce:YIL002C" "sce:YNL106C" "sce:YOR109W" "sce:YPL268W" "sce:YJR110W"
# [6] "sce:YLR240W"
#
# $`sce:YNL267W`
# [1] "sce:YIL002C" "sce:YNL106C" "sce:YOR109W" "sce:YPL268W" "sce:YJR110W"
# [6] "sce:YLR240W"
#
# $`sce:YBR029C`
# character(0)
#
# $`sce:YIL002C`
# [1] "sce:YPL268W"
#
# $`sce:YNL106C`
# [1] "sce:YPL268W"
#
# $`sce:YOR109W`
# [1] "sce:YPL268W"
#
# $`sce:YDR173C`
# [1] "sce:YDR173C" "sce:YOL065C" "sce:YDR315C"
#
# $`sce:YDR287W`
# [1] "sce:YDR287W" "sce:YHR046C"
#
# $`sce:YHR046C`
# [1] "sce:YDR287W" "sce:YHR046C"
#
# $`sce:YOL065C`
# [1] "sce:YPL268W" "sce:YDR173C"
#
# $`sce:YJR110W`
# [1] "sce:YLR240W"
#
# $`sce:YDR017C`
# [1] "sce:YDR315C" "sce:YLR410W"
#
# $`sce:YLR410W`
# [1] "sce:YDR315C" "sce:YDR017C"
#
# $`sce:YLR240W`
# character(0)
#
# $`sce:YBL105C`
# character(0)
#
# $`sce:YKL212W`
# [1] "sce:YFR019W" "sce:YPL268W" "sce:YLR240W" "sce:YJR110W" "sce:YPR113W"
# [6] "sce:YIL002C" "sce:YNL106C" "sce:YOR109W" "sce:YDR208W"

# %%
gR

# %%
nodes(gR)

# %%
library(pathview)

# %%
download.kegg(pathway.id = "00010", species = "sce", kegg.dir = ".",file.type=c("xml"))
